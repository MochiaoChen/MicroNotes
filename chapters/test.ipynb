# %%
cell_height, cell_width = 4, 4  
n_rows, n_cols = 2, 2  

line1 = ("-" * cell_width).join(["+"] * (n_cols + 1))
line2 = line1.replace("-", " ").replace("+", "|")

for i in range((cell_height + 1) * n_rows + 1): 
    print(line1 if i % (cell_height + 1) == 0 else line2)
# Out:
# +----+----+
# |    |    |
# |    |    |
# |    |    |
# |    |    |
# +----+----+
# |    |    |
# |    |    |
# |    |    |
# |    |    |
# +----+----+
